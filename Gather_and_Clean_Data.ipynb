# %% [markdown]
# # Gather & Clean Data
# ## Step 1: Import Modules & API keys

# %%
# Import modules
import pandas as pd
import json
import requests
import pprint
import os

# Career One Stop API credentials
from config import token
from config import userId

# College Scorecard API key
from config import api_key

# %% [markdown]
# ## Step 2: Get list of occupations
# Source: https://www.onetonline.org/find/career?c=11&g=Go

# %%
# Pull occupations from csv file
file_path = os.path.join('Resources','Information_Technology.csv')
o_net_df =  pd.read_csv(file_path, encoding="ISO-8859-1")

# %% [markdown]
# ## Step 3: Get Occupation Wages & Education
# Source: https://www.careeronestop.org/Developers/WebAPI/web-api.aspx
# #### Education Level Key:
# 1. Less than high school diploma
# 2. High school diploma or equivalent
# 3. Some college, no degree
# 4. Associate's degree
# 5. Bachelor's degree
# 6. Master's degree
# 7. Doctoral or professional degree

# %%
# Configure API Header & Location param
headers = {'Authorization': f'Bearer {token}'}
location = 'FL'

# Create variables used within loop
occupation_df = pd.DataFrame()
i = 0

# Loop through each IT occupation from step 2 and retrieve occupation details.
for code in o_net_df['Code']:

    # API call to retrieve occupation details
    keyword = o_net_df['Code'][i]
    params = {'wages': 'true'
             ,'training': 'true'
             }
    api_url = f'https://api.careeronestop.org/v1/occupation/{userId}/{keyword}/{location}?'
    response = requests.get(api_url, headers=headers, params=params).json()
 
    # Loop through wage rates & assign the annual & hourly valiables accordingly
    annual = 0
    hourly = 0
    for row in response['OccupationDetail'][0]['Wages']['StateWagesList']:
        if row['RateType'] == 'Annual':
            annual = row
        elif row['RateType'] == 'Hourly':
            hourly = row
    
    # Loop through education levels & assign valiables accordingly
    EducationLevel_1 = 0
    EducationLevel_2 = 0
    EducationLevel_3 = 0
    EducationLevel_4 = 0
    EducationLevel_5 = 0
    EducationLevel_6 = 0
    EducationLevel_7 = 0

    for row in response['OccupationDetail'][0]['EducationTraining']['EducationType']:
        if row['EducationLevel'] == 'Less than high school diploma':
            EducationLevel_1 = row['Value']
        elif row['EducationLevel'] == 'High school diploma or equivalent':
            EducationLevel_2 = row['Value']
        elif row['EducationLevel'] == 'Some college, no degree':
            EducationLevel_3 = row['Value']
        elif row['EducationLevel'] == "Associate's degree":
            EducationLevel_4 = row['Value']
        elif row['EducationLevel'] == "Bachelor's degree":
            EducationLevel_5 = row['Value']
        elif row['EducationLevel'] == "Master's degree":
            EducationLevel_6 = row['Value']
        elif row['EducationLevel'] == 'Doctoral or professional degree':
            EducationLevel_7 = row['Value']
    
    # Build DataFrame with this instance
    df = pd.DataFrame(
            {'Occupation':[o_net_df['Occupation'][i]]
            ,'Career Pathway':o_net_df['Career Pathway'][i]
            ,'OnetTitle':[response['OccupationDetail'][0]['OnetTitle']]
            ,'OnetDescription':[response['OccupationDetail'][0]['OnetDescription']]
            ,'Annual Wage - Pct10':[annual['Pct10']]
            ,'Annual Wage - Pct25':[annual['Pct25']]
            ,'Annual Wage - Median':[annual['Median']]
            ,'Annual Wage - Pct75':[annual['Pct75']]
            ,'Annual Wage - Pct90':[annual['Pct90']]
            ,'Hourly Wage - Pct10':[hourly['Pct10']]
            ,'Hourly Wage - Pct25':[hourly['Pct25']]
            ,'Hourly Wage - Median':[hourly['Median']]
            ,'Hourly Wage - Pct75':[hourly['Pct75']]
            ,'Hourly Wage - Pct90':[hourly['Pct90']]
            ,'WageYear':[response['OccupationDetail'][0]['Wages']['WageYear']]
            ,'BrightOutlook':[response['OccupationDetail'][0]['BrightOutlook']]
            ,'EducationLevel_1':[EducationLevel_1]
            ,'EducationLevel_2':[EducationLevel_2]
            ,'EducationLevel_3':[EducationLevel_3]
            ,'EducationLevel_4':[EducationLevel_4]
            ,'EducationLevel_5':[EducationLevel_5]
            ,'EducationLevel_6':[EducationLevel_6]
            ,'EducationLevel_7':[EducationLevel_7]
            ,'EducationCode':[response['OccupationDetail'][0]['EducationTraining']['EducationCode']]
            ,'EducationTitle':[response['OccupationDetail'][0]['EducationTraining']['EducationTitle']]
            ,'ExperienceCode':[response['OccupationDetail'][0]['EducationTraining']['ExperienceCode']]
            ,'ExperienceTitle':[response['OccupationDetail'][0]['EducationTraining']['ExperienceTitle']]
            ,'TrainingCode':[response['OccupationDetail'][0]['EducationTraining']['TrainingCode']]
            ,'TrainingTitle':[response['OccupationDetail'][0]['EducationTraining']['TrainingTitle']]
            ,'EducationOccupationTitle':[response['OccupationDetail'][0]['EducationTraining']['OccupationTitle']]
            }, index=[o_net_df['Code'][i]])
    occupation_df = occupation_df.append(df)
    i += 1

occupation_df.head()
# Out:
#                                        Occupation  \
# 15-2051.01         Business Intelligence Analysts
# 15-1299.00        Computer Occupations, All Other
# 15-1299.08  Computer Systems Engineers/Architects
# 15-1232.00      Computer User Support Specialists
# 15-1243.01           Data Warehousing Specialists
#
#                               Career Pathway  \
# 15-2051.01  Information Support and Services
# 15-1299.00  Information Support and Services
# 15-1299.08  Information Support and Services
# 15-1232.00  Information Support and Services
# 15-1243.01  Information Support and Services
#
#                                         OnetTitle  \
# 15-2051.01         Business Intelligence Analysts
# 15-1299.00        Computer Occupations, All Other
# 15-1299.08  Computer Systems Engineers/Architects
# 15-1232.00      Computer User Support Specialists
# 15-1243.01           Data Warehousing Specialists
#
#                                               OnetDescription  \
# 15-2051.01  Produce financial and market intelligence by q...
# 15-1299.00    All computer occupations not listed separately.
# 15-1299.08  Design and develop solutions to complex applic...
# 15-1232.00  Provide technical assistance to computer users...
# 15-1243.01  Design, model, or implement corporate data war...
#
#            Annual Wage - Pct10 Annual Wage - Pct25 Annual Wage - Median  \
# 15-2051.01               44810               54300                64250
# 15-1299.00               31020               45760                71250
# 15-1299.08               31020               45760                71250
# 15-1232.00               30040               36570                46970
# 15-1243.01               45430               63700                90230
#
#            Annual Wage - Pct75 Annual Wage - Pct90 Hourly Wage - Pct10  ...  \
# 15-2051.01               98980              138330               21.55  ...
# 15-1299.00               98880              123080               14.91  ...
# 15-1299.08               98880              123080               14.91  ...
# 15-1232.00               61660               79350               14.44  ...
# 15-1243.01              116170              134290               21.84  ...
#
#            EducationLevel_5 EducationLevel_6 EducationLevel_7 EducationCode  \
# 15-2051.01             37.5               36             14.5             3
# 15-1299.00             43.6               20              2.2             3
# 15-1299.08             43.6               20              2.2             3
# 15-1232.00               37             10.7                1             6
# 15-1243.01             46.9             25.2              2.7             3
#
#                      EducationTitle ExperienceCode     ExperienceTitle  \
# 15-2051.01        Bachelor's degree              3  No work experience
# 15-1299.00        Bachelor's degree              3  No work experience
# 15-1299.08        Bachelor's degree              3  No work experience
# 15-1232.00  Some college, no degree              3  No work experience
# 15-1243.01        Bachelor's degree              3  No work experience
#
#            TrainingCode           TrainingTitle  \
# 15-2051.01            6  No on-the-job training
# 15-1299.00            6  No on-the-job training
# 15-1299.08            6  No on-the-job training
# 15-1232.00            6  No on-the-job training
# 15-1243.01            6  No on-the-job training
#
#                                      EducationOccupationTitle
# 15-2051.01  Data Scientists and Mathematical Science Occup...
# 15-1299.00                    Computer Occupations, All Other
# 15-1299.08                    Computer Occupations, All Other
# 15-1232.00                  Computer User Support Specialists
# 15-1243.01             Database Administrators and Architects
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Step 4: Pull tuition data for Florida schools
# Source: https://collegescorecard.ed.gov/data/
# #### Degree Level Key:
# 1. Undergraduate Certificates or Diplomas
# 2. Associate’s Degrees
# 3. Bachelor’s Degrees
# 4. Post-Baccalaureate Certificates
# 5. Master’s Degrees
# 6. Doctoral Degrees
# 7. First Professional Degrees
# 8. Graduate / Professional Certificates

# %%
# Params
base_url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?'
state = 'school.state=FL&fields=id,school.name,school.state' 
year = 2018
cost_per = f'{year}.cost.attendance.academic_year,{year}.cost.attendance.program_year'
predom_type = 'school.degrees_awarded.predominant_recoded'
response_ls = []
# Loop through pages of API call

for page in range(20):
    
    # Grab the base url
    url = f'{base_url}{state},{cost_per},{predom_type}&api_key={api_key}&page={page}'
    response = requests.get(url).json()
    response_ls.append(response)
response_ls
# Out:
# [{'metadata': {'total': 387, 'page': 0, 'per_page': 20},
#   'results': [{'school.name': 'Palm Beach Academy of Health & Beauty',
#     'school.state': 'FL',
#     'id': 449490,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25572,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'SABER College',
#     'school.state': 'FL',
#     'id': 449506,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': 19233,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Pensacola School of Massage Therapy & Health Careers',
#     'school.state': 'FL',
#     'id': 449533,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 21608,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Paul Mitchell the School-Tampa',
#     'school.state': 'FL',
#     'id': 449959,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 21596,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida National University Training Center',
#     'school.state': 'FL',
#     'id': 40884402,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Future-Tech Institute',
#     'school.state': 'FL',
#     'id': 459310,
#     '2018.cost.attendance.academic_year': 11429,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Fred K Marchman Technical College',
#     'school.state': 'FL',
#     'id': 459329,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 8557,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Boca Beauty Academy',
#     'school.state': 'FL',
#     'id': 481483,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 15907,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'DeVry University-Florida',
#     'school.state': 'FL',
#     'id': 482459,
#     '2018.cost.attendance.academic_year': 31391,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida Career College-West Palm Beach',
#     'school.state': 'FL',
#     'id': 487393,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 34445,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Career College-Hialeah',
#     'school.state': 'FL',
#     'id': 487409,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 34606,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Career College-Jacksonville',
#     'school.state': 'FL',
#     'id': 487436,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 35778,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Med Academy',
#     'school.state': 'FL',
#     'id': 488059,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 23794,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Center for Neurosomatic Studies',
#     'school.state': 'FL',
#     'id': 488226,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 33327,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'National Personal Training Institute',
#     'school.state': 'FL',
#     'id': 488280,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 13718,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Treasure Coast Technical College',
#     'school.state': 'FL',
#     'id': 486150,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'San Ignacio University',
#     'school.state': 'FL',
#     'id': 486239,
#     '2018.cost.attendance.academic_year': 16533,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Keiser University - Residential',
#     'school.state': 'FL',
#     'id': 13508116,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'The Salon Professional Academy-Delray Beach',
#     'school.state': 'FL',
#     'id': 492360,
#     '2018.cost.attendance.program_year': 28570,
#     '2018.cost.attendance.academic_year': None,
#     'school.degrees_awarded.predominant_recoded': None},
#    {'school.name': 'Suncoast Technical Education Center',
#     'school.state': 'FL',
#     'id': 491783,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None,
#     'school.degrees_awarded.predominant_recoded': None}]},
#  {'metadata': {'total': 387, 'page': 1, 'per_page': 20},
#   'results': [{'school.name': 'Empire Beauty School-Tampa',
#     'school.state': 'FL',
#     'id': 491136,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 20283,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Columbia College - NAS Jacksonville',
#     'school.state': 'FL',
#     'id': 17706504,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Everglades University - Tampa',
#     'school.state': 'FL',
#     'id': 38561903,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Medical Prep Institute of Tampa Bay',
#     'school.state': 'FL',
#     'id': 490179,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': 24319,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Gadsden Technical Institute',
#     'school.state': 'FL',
#     'id': 490090,
#     '2018.cost.attendance.program_year': 10229,
#     '2018.cost.attendance.academic_year': None,
#     'school.degrees_awarded.predominant_recoded': None},
#    {'school.name': 'Gwinnett Institute',
#     'school.state': 'FL',
#     'id': 490559,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 19013,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Polytechnic University',
#     'school.state': 'FL',
#     'id': 482936,
#     '2018.cost.attendance.academic_year': 20689,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'McDougle Technical  Institute',
#     'school.state': 'FL',
#     'id': 484039,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 22532,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'More Tech Institute',
#     'school.state': 'FL',
#     'id': 483470,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 22694,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'University of Florida-Online',
#     'school.state': 'FL',
#     'id': 484473,
#     '2018.cost.attendance.academic_year': 17405,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'InterAmerican Technical Institute',
#     'school.state': 'FL',
#     'id': 483869,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 24867,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Parisian Spa Institute',
#     'school.state': 'FL',
#     'id': 483896,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Hollywood Institute of Beauty Careers-West Palm Beach',
#     'school.state': 'FL',
#     'id': 485379,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25131,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Merryfield School of Pet Grooming',
#     'school.state': 'FL',
#     'id': 135559,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 26314,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Kaizen Beauty Academy',
#     'school.state': 'FL',
#     'id': 481313,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 21325,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Beauty Academy of South Florida',
#     'school.state': 'FL',
#     'id': 460969,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 31687,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'D A Dorsey Technical College',
#     'school.state': 'FL',
#     'id': 461306,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 5420,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Vocational Institute',
#     'school.state': 'FL',
#     'id': 476939,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 30786,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'SAE Institute of Technology-Miami',
#     'school.state': 'FL',
#     'id': 476966,
#     '2018.cost.attendance.program_year': 29416,
#     '2018.cost.attendance.academic_year': None,
#     'school.degrees_awarded.predominant_recoded': None},
#    {'school.name': 'Florida Institute of Technology-Online',
#     'school.state': 'FL',
#     'id': 480569,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 2, 'per_page': 20},
#   'results': [{'school.name': 'Tulsa Welding School-Jacksonville',
#     'school.state': 'FL',
#     'id': 476063,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 26405,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida School of Traditional Midwifery',
#     'school.state': 'FL',
#     'id': 457350,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'American Academy of Cosmetology',
#     'school.state': 'FL',
#     'id': 457396,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 19065,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Summit Salon Academy',
#     'school.state': 'FL',
#     'id': 457420,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 18841,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Summit Salon Academy-Gainesville',
#     'school.state': 'FL',
#     'id': 457439,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 18848,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Concorde Career Institute-Orlando',
#     'school.state': 'FL',
#     'id': 460190,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 27045,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Keiser University-Ft Myers',
#     'school.state': 'FL',
#     'id': 13508113,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Rasmussen College-Tampa/Brandon',
#     'school.state': 'FL',
#     'id': 13830903,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Strayer University-Orlando East Campus',
#     'school.state': 'FL',
#     'id': 44903803,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Strayer University-Palm Beach Gardens Campus',
#     'school.state': 'FL',
#     'id': 44903806,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Strayer University-Miramar Campus',
#     'school.state': 'FL',
#     'id': 44903809,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Remington College-Heathrow Campus',
#     'school.state': 'FL',
#     'id': 460783,
#     '2018.cost.attendance.academic_year': 21529,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Millennia Atlantic University',
#     'school.state': 'FL',
#     'id': 461883,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'University of South Florida-St Petersburg',
#     'school.state': 'FL',
#     'id': 448840,
#     '2018.cost.attendance.academic_year': 19849,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Fortis Institute-Pensacola',
#     'school.state': 'FL',
#     'id': 455479,
#     '2018.cost.attendance.academic_year': 28835,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Empire Beauty School-Lauderhill',
#     'school.state': 'FL',
#     'id': 456126,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 21296,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Chamberlain University-Florida',
#     'school.state': 'FL',
#     'id': 457129,
#     '2018.cost.attendance.academic_year': 30279,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Polytechnic University of Puerto Rico-Orlando',
#     'school.state': 'FL',
#     'id': 456490,
#     '2018.cost.attendance.academic_year': 21431,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'South Florida Bible College and Theological Seminary',
#     'school.state': 'FL',
#     'id': 366003,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'College of Business and Technology-Main Campus',
#     'school.state': 'FL',
#     'id': 449083,
#     '2018.cost.attendance.academic_year': 18552,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 3, 'per_page': 20},
#   'results': [{'school.name': 'Academy for Five Element Acupuncture',
#     'school.state': 'FL',
#     'id': 451079,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Miami Regional University',
#     'school.state': 'FL',
#     'id': 451103,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': 30453,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Aveda Institute-South Florida',
#     'school.state': 'FL',
#     'id': 451149,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 23388,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'American Advanced Technicians Institute',
#     'school.state': 'FL',
#     'id': 444370,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 27361,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Flagler College-Tallahassee',
#     'school.state': 'FL',
#     'id': 444990,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Keiser University-Daytona',
#     'school.state': 'FL',
#     'id': 13508103,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Keiser University-Orlando',
#     'school.state': 'FL',
#     'id': 13508106,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'New College of Florida',
#     'school.state': 'FL',
#     'id': 262129,
#     '2018.cost.attendance.academic_year': 20624,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Acupuncture and Massage College',
#     'school.state': 'FL',
#     'id': 439969,
#     '2018.cost.attendance.academic_year': 34098,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Atlantic Institute of Oriental Medicine',
#     'school.state': 'FL',
#     'id': 439446,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'International Training Careers',
#     'school.state': 'FL',
#     'id': 439686,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25530,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Academy for Nursing and Health Occupations',
#     'school.state': 'FL',
#     'id': 412173,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 26939,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'New Professions Technical Institute',
#     'school.state': 'FL',
#     'id': 434469,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25093,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'City College-Miami',
#     'school.state': 'FL',
#     'id': 434539,
#     '2018.cost.attendance.academic_year': 26030,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Eastern Florida State College',
#     'school.state': 'FL',
#     'id': 132693,
#     '2018.cost.attendance.academic_year': 10133,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Broward College',
#     'school.state': 'FL',
#     'id': 132709,
#     '2018.cost.attendance.academic_year': 13429,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Johnson University Florida',
#     'school.state': 'FL',
#     'id': 132879,
#     '2018.cost.attendance.academic_year': 22322,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'University of Central Florida',
#     'school.state': 'FL',
#     'id': 132903,
#     '2018.cost.attendance.academic_year': 21034,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Charlotte Technical College',
#     'school.state': 'FL',
#     'id': 132976,
#     '2018.cost.attendance.academic_year': 15710,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Embry-Riddle Aeronautical University-Daytona Beach',
#     'school.state': 'FL',
#     'id': 133553,
#     '2018.cost.attendance.academic_year': 51728,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 4, 'per_page': 20},
#   'results': [{'school.name': 'Florida Atlantic University',
#     'school.state': 'FL',
#     'id': 133669,
#     '2018.cost.attendance.academic_year': 19559,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Trinity International University-Florida',
#     'school.state': 'FL',
#     'id': 135610,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'University of Miami',
#     'school.state': 'FL',
#     'id': 135726,
#     '2018.cost.attendance.academic_year': 65298,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'The College of the Florida Keys',
#     'school.state': 'FL',
#     'id': 133960,
#     '2018.cost.attendance.academic_year': 18506,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida Memorial University',
#     'school.state': 'FL',
#     'id': 133979,
#     '2018.cost.attendance.academic_year': 26552,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida Southern College',
#     'school.state': 'FL',
#     'id': 134079,
#     '2018.cost.attendance.academic_year': 49296,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Paul Mitchell the School-Jacksonville',
#     'school.state': 'FL',
#     'id': 136109,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 22047,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Northwest Florida State College',
#     'school.state': 'FL',
#     'id': 136233,
#     '2018.cost.attendance.academic_year': 11774,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Orange Technical College-Orlando Campus',
#     'school.state': 'FL',
#     'id': 136303,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 17225,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Palm Beach Atlantic University',
#     'school.state': 'FL',
#     'id': 136330,
#     '2018.cost.attendance.academic_year': 45037,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Pasco-Hernando State College',
#     'school.state': 'FL',
#     'id': 136400,
#     '2018.cost.attendance.academic_year': 10760,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Pensacola State College',
#     'school.state': 'FL',
#     'id': 136473,
#     '2018.cost.attendance.academic_year': 9495,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Polk State College',
#     'school.state': 'FL',
#     'id': 136516,
#     '2018.cost.attendance.academic_year': 12682,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Radford M Locklin Technical College',
#     'school.state': 'FL',
#     'id': 136659,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 14869,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Robert Morgan Educational Center and Technical College',
#     'school.state': 'FL',
#     'id': 136826,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 13714,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'University of Florida',
#     'school.state': 'FL',
#     'id': 134130,
#     '2018.cost.attendance.academic_year': 21034,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Gulf Coast State College',
#     'school.state': 'FL',
#     'id': 134343,
#     '2018.cost.attendance.academic_year': 8680,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Hobe Sound Bible College',
#     'school.state': 'FL',
#     'id': 134510,
#     '2018.cost.attendance.academic_year': 14314,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Hollywood Institute of Beauty Careers',
#     'school.state': 'FL',
#     'id': 134529,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 27001,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Gateway College',
#     'school.state': 'FL',
#     'id': 135160,
#     '2018.cost.attendance.academic_year': 9521,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 5, 'per_page': 20},
#   'results': [{'school.name': 'Lake Technical College',
#     'school.state': 'FL',
#     'id': 135179,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 14870,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Lively Technical College',
#     'school.state': 'FL',
#     'id': 135276,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 13982,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Rollins College',
#     'school.state': 'FL',
#     'id': 136950,
#     '2018.cost.attendance.academic_year': 65487,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'First Coast Technical College',
#     'school.state': 'FL',
#     'id': 137023,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 17220,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Suncoast Technical College',
#     'school.state': 'FL',
#     'id': 137120,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 18847,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Seminole State College of Florida',
#     'school.state': 'FL',
#     'id': 137209,
#     '2018.cost.attendance.academic_year': 13060,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'St. Thomas University',
#     'school.state': 'FL',
#     'id': 137476,
#     '2018.cost.attendance.academic_year': 41512,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Stetson University',
#     'school.state': 'FL',
#     'id': 137546,
#     '2018.cost.attendance.academic_year': 59208,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Riveroak Technical College',
#     'school.state': 'FL',
#     'id': 137713,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 18983,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Tallahassee Community College',
#     'school.state': 'FL',
#     'id': 137759,
#     '2018.cost.attendance.academic_year': 8501,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Big Bend Technical College',
#     'school.state': 'FL',
#     'id': 137856,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 13866,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Trinity Baptist College',
#     'school.state': 'FL',
#     'id': 137953,
#     '2018.cost.attendance.academic_year': 21721,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Webber International University',
#     'school.state': 'FL',
#     'id': 138293,
#     '2018.cost.attendance.academic_year': 39973,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Rasmussen College-Florida',
#     'school.state': 'FL',
#     'id': 138309,
#     '2018.cost.attendance.academic_year': 23123,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'William T McFatter Technical College',
#     'school.state': 'FL',
#     'id': 138479,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Sarasota School of Massage Therapy',
#     'school.state': 'FL',
#     'id': 406149,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 26066,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'American Institute of Beauty',
#     'school.state': 'FL',
#     'id': 447883,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 20272,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Cambridge Institute of Allied Health & Technology',
#     'school.state': 'FL',
#     'id': 446109,
#     '2018.cost.attendance.academic_year': 22869,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Universal Career School',
#     'school.state': 'FL',
#     'id': 446589,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25515,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Keiser University-Tampa',
#     'school.state': 'FL',
#     'id': 13508109,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 6, 'per_page': 20},
#   'results': [{'school.name': 'Keiser University-Pembroke Pines',
#     'school.state': 'FL',
#     'id': 13508110,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Artistic Nails and Beauty Academy-Tampa',
#     'school.state': 'FL',
#     'id': 378886,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 17834,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Barber Academy',
#     'school.state': 'FL',
#     'id': 441380,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 20352,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Education Institute',
#     'school.state': 'FL',
#     'id': 441423,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 24352,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Tulsa Welding School-Jacksonville',
#     'school.state': 'FL',
#     'id': 442329,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 32223,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Gulf Coast University',
#     'school.state': 'FL',
#     'id': 433660,
#     '2018.cost.attendance.academic_year': 19237,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Daytona State College',
#     'school.state': 'FL',
#     'id': 133386,
#     '2018.cost.attendance.academic_year': 11107,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Edward Waters College',
#     'school.state': 'FL',
#     'id': 133526,
#     '2018.cost.attendance.academic_year': 24933,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida Agricultural and Mechanical University',
#     'school.state': 'FL',
#     'id': 133650,
#     '2018.cost.attendance.academic_year': 22716,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida College',
#     'school.state': 'FL',
#     'id': 133809,
#     '2018.cost.attendance.academic_year': 29729,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Concorde Career Institute-Tampa',
#     'school.state': 'FL',
#     'id': 133863,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 26518,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'City College-Fort Lauderdale',
#     'school.state': 'FL',
#     'id': 244233,
#     '2018.cost.attendance.academic_year': 29610,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Meridian College',
#     'school.state': 'FL',
#     'id': 244279,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 20417,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Sunstate Academy',
#     'school.state': 'FL',
#     'id': 362700,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 29917,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Southern Technical College',
#     'school.state': 'FL',
#     'id': 366553,
#     '2018.cost.attendance.academic_year': 22613,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Universal Technical Institute-Auto Motorcycle & Marine Mechanics Institute Division-Orlando',
#     'school.state': 'FL',
#     'id': 369400,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25846,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Erwin Technical College',
#     'school.state': 'FL',
#     'id': 369419,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 14676,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'National Aviation Academy of Tampa Bay',
#     'school.state': 'FL',
#     'id': 378956,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 26749,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'La Belle Beauty Academy',
#     'school.state': 'FL',
#     'id': 383163,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25690,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'ASM Beauty World Academy',
#     'school.state': 'FL',
#     'id': 391546,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 7, 'per_page': 20},
#   'results': [{'school.name': 'Beauty Schools of America-Hialeah',
#     'school.state': 'FL',
#     'id': 419660,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 27052,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Cortiva Institute-Miami',
#     'school.state': 'FL',
#     'id': 420103,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25513,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Marion Technical College',
#     'school.state': 'FL',
#     'id': 419226,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Compu-Med Vocational Careers Corp',
#     'school.state': 'FL',
#     'id': 423120,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 13794,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Miami Ad School-Wynwood',
#     'school.state': 'FL',
#     'id': 428000,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Southeastern College-West Palm Beach',
#     'school.state': 'FL',
#     'id': 428170,
#     '2018.cost.attendance.academic_year': 31854,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Santa Fe College',
#     'school.state': 'FL',
#     'id': 137096,
#     '2018.cost.attendance.academic_year': 14258,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Everglades University',
#     'school.state': 'FL',
#     'id': 385619,
#     '2018.cost.attendance.academic_year': 32070,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Johnson & Wales University-North Miami',
#     'school.state': 'FL',
#     'id': 414823,
#     '2018.cost.attendance.academic_year': 45727,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida SouthWestern State College',
#     'school.state': 'FL',
#     'id': 133508,
#     '2018.cost.attendance.academic_year': 13208,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida State College at Jacksonville',
#     'school.state': 'FL',
#     'id': 133702,
#     '2018.cost.attendance.academic_year': 9085,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Concorde Career Institute-Jacksonville',
#     'school.state': 'FL',
#     'id': 133845,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 33410,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Traviss Technical College',
#     'school.state': 'FL',
#     'id': 135522,
#     '2018.cost.attendance.academic_year': 13133,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'AdventHealth University',
#     'school.state': 'FL',
#     'id': 133872,
#     '2018.cost.attendance.academic_year': 24338,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida Institute of Ultrasound Inc',
#     'school.state': 'FL',
#     'id': 133942,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Orange Technical College-Mid Florida Campus',
#     'school.state': 'FL',
#     'id': 135735,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'North Florida College',
#     'school.state': 'FL',
#     'id': 136145,
#     '2018.cost.attendance.academic_year': 9051,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'University of North Florida',
#     'school.state': 'FL',
#     'id': 136172,
#     '2018.cost.attendance.academic_year': 19691,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Nova Southeastern University',
#     'school.state': 'FL',
#     'id': 136215,
#     '2018.cost.attendance.academic_year': 47432,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Palm Beach State College',
#     'school.state': 'FL',
#     'id': 136358,
#     '2018.cost.attendance.academic_year': 9677,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 8, 'per_page': 20},
#   'results': [{'school.name': 'Ridge Technical College',
#     'school.state': 'FL',
#     'id': 136765,
#     '2018.cost.attendance.academic_year': 27368,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida Technical College',
#     'school.state': 'FL',
#     'id': 134112,
#     '2018.cost.attendance.academic_year': 19611,
#     '2018.cost.attendance.program_year': None,
#     'school.degrees_awarded.predominant_recoded': None},
#    {'school.name': 'Fort Pierce Beauty Academy',
#     'school.state': 'FL',
#     'id': 134228,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 15778,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Hillsborough Community College',
#     'school.state': 'FL',
#     'id': 134495,
#     '2018.cost.attendance.academic_year': 9347,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Indian River State College',
#     'school.state': 'FL',
#     'id': 134608,
#     '2018.cost.attendance.academic_year': 6419,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Jacksonville University',
#     'school.state': 'FL',
#     'id': 134945,
#     '2018.cost.attendance.academic_year': 52073,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'La Belle Beauty School',
#     'school.state': 'FL',
#     'id': 135142,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 16502,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Lake-Sumter State College',
#     'school.state': 'FL',
#     'id': 135188,
#     '2018.cost.attendance.academic_year': 9383,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Saint Leo University',
#     'school.state': 'FL',
#     'id': 137032,
#     '2018.cost.attendance.academic_year': 36961,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'St Petersburg College',
#     'school.state': 'FL',
#     'id': 137078,
#     '2018.cost.attendance.academic_year': 11250,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Sheridan Technical College',
#     'school.state': 'FL',
#     'id': 137245,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 12452,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'South Florida State College',
#     'school.state': 'FL',
#     'id': 137315,
#     '2018.cost.attendance.academic_year': 10455,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Tom P Haney Technical Center',
#     'school.state': 'FL',
#     'id': 137865,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 12235,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Trinity College of Florida',
#     'school.state': 'FL',
#     'id': 137962,
#     '2018.cost.attendance.academic_year': 24745,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Fashion Focus Hair Academy',
#     'school.state': 'FL',
#     'id': 138132,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 21800,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Warner University',
#     'school.state': 'FL',
#     'id': 138275,
#     '2018.cost.attendance.academic_year': 34001,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Orange Technical College-Westside Campus',
#     'school.state': 'FL',
#     'id': 138372,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 15774,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Orange Technical College-Winter Park Campus',
#     'school.state': 'FL',
#     'id': 138488,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25789,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'The Baptist College of Florida',
#     'school.state': 'FL',
#     'id': 132408,
#     '2018.cost.attendance.academic_year': 17812,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Bethune-Cookman University',
#     'school.state': 'FL',
#     'id': 132602,
#     '2018.cost.attendance.academic_year': 27817,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 9, 'per_page': 20},
#   'results': [{'school.name': 'Carlos Albizu University-Miami',
#     'school.state': 'FL',
#     'id': 132842,
#     '2018.cost.attendance.academic_year': 37421,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Lorenzo Walker Technical College',
#     'school.state': 'FL',
#     'id': 133155,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 11743,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'South University-West Palm Beach',
#     'school.state': 'FL',
#     'id': 133465,
#     '2018.cost.attendance.academic_year': 27783,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Eckerd College',
#     'school.state': 'FL',
#     'id': 133492,
#     '2018.cost.attendance.academic_year': 59005,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'St. John Vianney College Seminary',
#     'school.state': 'FL',
#     'id': 137272,
#     '2018.cost.attendance.academic_year': 37200,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Rasmussen College-New Port Richey',
#     'school.state': 'FL',
#     'id': 13830901,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Strayer University-Tampa East Campus',
#     'school.state': 'FL',
#     'id': 44903801,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Strayer University-Sand Lake Campus',
#     'school.state': 'FL',
#     'id': 44903804,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Everglades University - Miami',
#     'school.state': 'FL',
#     'id': 38561904,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None,
#     'school.degrees_awarded.predominant_recoded': None},
#    {'school.name': 'Maynard A. Traviss Technical College - Central Florida Aerospace Academy',
#     'school.state': 'FL',
#     'id': 13552201,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'HCI College - Fort Lauderdale Campus',
#     'school.state': 'FL',
#     'id': 49005401,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Pets Playground Grooming School',
#     'school.state': 'FL',
#     'id': 491534,
# ...
#    {'school.name': 'Ave Maria School of Law',
#     'school.state': 'FL',
#     'id': 442295,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'South Florida Institute of Technology',
#     'school.state': 'FL',
#     'id': 443252,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 13871,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Yeshivah Gedolah Rabbinical College',
#     'school.state': 'FL',
#     'id': 363712,
#     '2018.cost.attendance.academic_year': 17300,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Fortis College-Orange Park',
#     'school.state': 'FL',
#     'id': 439792,
#     '2018.cost.attendance.academic_year': 28578,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Southern Technical College',
#     'school.state': 'FL',
#     'id': 446552,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': 20842,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Everglades University-Sarasota',
#     'school.state': 'FL',
#     'id': 38561902,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'College of Business and Technology-Hialeah',
#     'school.state': 'FL',
#     'id': 449092,
#     '2018.cost.attendance.academic_year': 17552,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Atlantic Technical College',
#     'school.state': 'FL',
#     'id': 132374,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 10779,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Barry University',
#     'school.state': 'FL',
#     'id': 132471,
#     '2018.cost.attendance.academic_year': 43524,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Lynn University',
#     'school.state': 'FL',
#     'id': 132657,
#     '2018.cost.attendance.academic_year': 55100,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'College of Central Florida',
#     'school.state': 'FL',
#     'id': 132851,
#     '2018.cost.attendance.academic_year': 11792,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Chipola College',
#     'school.state': 'FL',
#     'id': 133021,
#     '2018.cost.attendance.academic_year': 8890,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Flagler College-St Augustine',
#     'school.state': 'FL',
#     'id': 133711,
#     '2018.cost.attendance.academic_year': 33047,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Manatee Technical College',
#     'school.state': 'FL',
#     'id': 135407,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 10828,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Concorde Career Institute-Miramar',
#     'school.state': 'FL',
#     'id': 133854,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 32207,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Miami Lakes Educational Center and Technical College',
#     'school.state': 'FL',
#     'id': 135647,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 11732,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Institute of Technology',
#     'school.state': 'FL',
#     'id': 133881,
#     '2018.cost.attendance.academic_year': 58508,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 17, 'per_page': 20},
#   'results': [{'school.name': 'Miami Dade College',
#     'school.state': 'FL',
#     'id': 135717,
#     '2018.cost.attendance.academic_year': 12378,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida International University',
#     'school.state': 'FL',
#     'id': 133951,
#     '2018.cost.attendance.academic_year': 19434,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Beauty Schools of America-Miami',
#     'school.state': 'FL',
#     'id': 135771,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 27245,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Career College-Miami',
#     'school.state': 'FL',
#     'id': 133997,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 34977,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida State University',
#     'school.state': 'FL',
#     'id': 134097,
#     '2018.cost.attendance.academic_year': 21623,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Cortiva Institute-Maitland',
#     'school.state': 'FL',
#     'id': 438285,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25676,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Florida Coastal School of Law',
#     'school.state': 'FL',
#     'id': 434715,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Pinellas Technical College-St. Petersburg',
#     'school.state': 'FL',
#     'id': 137087,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 21659,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'L3 Commercial Training Solutions Airline Academy',
#     'school.state': 'FL',
#     'id': 429012,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 116377,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Praxis Institute',
#     'school.state': 'FL',
#     'id': 430582,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 11786,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Robert Fiance Beauty Schools',
#     'school.state': 'FL',
#     'id': 186274,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 38873,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Pinellas Technical College-Clearwater',
#     'school.state': 'FL',
#     'id': 136491,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 27342,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Saint Vincent de Paul Regional Seminary',
#     'school.state': 'FL',
#     'id': 136701,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None,
#     'school.degrees_awarded.predominant_recoded': None},
#    {'school.name': 'Ringling College of Art and Design',
#     'school.state': 'FL',
#     'id': 136774,
#     '2018.cost.attendance.academic_year': 64554,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Full Sail University',
#     'school.state': 'FL',
#     'id': 134237,
#     '2018.cost.attendance.academic_year': 33965,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'George Stone Technical College',
#     'school.state': 'FL',
#     'id': 134291,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 12449,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'George T Baker Aviation Technical College',
#     'school.state': 'FL',
#     'id': 134307,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 7317,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Cortiva Institute-Florida',
#     'school.state': 'FL',
#     'id': 134574,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 25190,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'International Academy',
#     'school.state': 'FL',
#     'id': 134714,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 24916,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'AI Miami International University of Art and Design',
#     'school.state': 'FL',
#     'id': 134811,
#     '2018.cost.attendance.academic_year': 25650,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None}]},
#  {'metadata': {'total': 387, 'page': 18, 'per_page': 20},
#   'results': [{'school.name': 'Keiser University-Ft Lauderdale',
#     'school.state': 'FL',
#     'id': 135081,
#     '2018.cost.attendance.academic_year': 36356,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Fort Myers Technical College',
#     'school.state': 'FL',
#     'id': 135267,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 9240,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Lindsey Hopkins Technical College',
#     'school.state': 'FL',
#     'id': 135294,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 9281,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Loraines Academy & Spa',
#     'school.state': 'FL',
#     'id': 135337,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 22023,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'State College of Florida-Manatee-Sarasota',
#     'school.state': 'FL',
#     'id': 135391,
#     '2018.cost.attendance.academic_year': 17404,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Saint Johns River State College',
#     'school.state': 'FL',
#     'id': 137281,
#     '2018.cost.attendance.academic_year': 11062,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'University of South Florida-Main Campus',
#     'school.state': 'FL',
#     'id': 137351,
#     '2018.cost.attendance.academic_year': 20456,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Southeastern University',
#     'school.state': 'FL',
#     'id': 137564,
#     '2018.cost.attendance.academic_year': 35800,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': "Bene's Career Academy",
#     'school.state': 'FL',
#     'id': 137591,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 24275,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Talmudic College of Florida',
#     'school.state': 'FL',
#     'id': 137777,
#     '2018.cost.attendance.academic_year': 26650,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Altierus Career College-Tampa',
#     'school.state': 'FL',
#     'id': 137801,
#     '2018.cost.attendance.academic_year': 26136,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'The University of Tampa',
#     'school.state': 'FL',
#     'id': 137847,
#     '2018.cost.attendance.academic_year': 43178,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Valencia College',
#     'school.state': 'FL',
#     'id': 138187,
#     '2018.cost.attendance.academic_year': 10688,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Florida Panhandle Technical College',
#     'school.state': 'FL',
#     'id': 138284,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 20123,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'The University of West Florida',
#     'school.state': 'FL',
#     'id': 138354,
#     '2018.cost.attendance.academic_year': 16595,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Withlacoochee Technical College',
#     'school.state': 'FL',
#     'id': 138497,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 10715,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Cape Coral Technical College',
#     'school.state': 'FL',
#     'id': 431558,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Brewster Technical College',
#     'school.state': 'FL',
#     'id': 367875,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 10351,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Academy of Cosmetology',
#     'school.state': 'FL',
#     'id': 372462,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 18462,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Sunstate Academy',
#     'school.state': 'FL',
#     'id': 372718,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 28367,
#     '2018.cost.attendance.academic_year': None}]},
#  {'metadata': {'total': 387, 'page': 19, 'per_page': 20},
#   'results': [{'school.name': 'The Salon Professional Academy-Melbourne',
#     'school.state': 'FL',
#     'id': 385132,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 22475,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Herzing University-Winter Park',
#     'school.state': 'FL',
#     'id': 386472,
#     '2018.cost.attendance.academic_year': 27104,
#     'school.degrees_awarded.predominant_recoded': 2,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Cortiva Institute-Pompano',
#     'school.state': 'FL',
#     'id': 387925,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 27070,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'Schiller International University',
#     'school.state': 'FL',
#     'id': 404338,
#     '2018.cost.attendance.academic_year': 22027,
#     'school.degrees_awarded.predominant_recoded': 3,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Nouvelle Institute',
#     'school.state': 'FL',
#     'id': 409032,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 18081,
#     '2018.cost.attendance.academic_year': None},
#    {'school.name': 'College of Business and Technology-Miami Campus',
#     'school.state': 'FL',
#     'id': 417318,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.academic_year': None,
#     '2018.cost.attendance.program_year': None},
#    {'school.name': 'Okaloosa Technical College',
#     'school.state': 'FL',
#     'id': 433068,
#     'school.degrees_awarded.predominant_recoded': 1,
#     '2018.cost.attendance.program_year': 16479,
#     '2018.cost.attendance.academic_year': None}]}]

# %%
# Create DataFrame
school_df = pd.DataFrame()
page_num = 0
for page in response_ls: 

# Start of loop to append columns in DataFrame
    for x in response_ls[page_num]['results']:
        df = pd.DataFrame(
            {'School Name': [x['school.name']]
            ,'School State':[x['school.state']]
            ,'Degree Type': [x['school.degrees_awarded.predominant_recoded']]
            ,'Program Cost':[x[f'{year}.cost.attendance.program_year']]
            ,'Annual Cost':[x[f'{year}.cost.attendance.academic_year']]
            }, index = [x['id']])
        school_df = school_df.append(df)
    page_num += 1
# Display data
# len(school_df)
# school_df['School Name'].nunique()
school_df.head()
# Out:
#                                                 School Name School State  \
# 449490                Palm Beach Academy of Health & Beauty           FL
# 449506                                        SABER College           FL
# 449533    Pensacola School of Massage Therapy & Health C...           FL
# 449959                       Paul Mitchell the School-Tampa           FL
# 40884402        Florida National University Training Center           FL
#
#          Degree Type Program Cost Annual Cost
# 449490             1        25572        None
# 449506             2        19233        None
# 449533             1        21608        None
# 449959             1        21596        None
# 40884402           2         None        None

# %%
# Add total colum to DataFrame
school_df['Total Cost'] = ''

# Iterate through rows by degree type
for index, row in school_df.iterrows():
    if row['Annual Cost'] == None:
        row['Total Cost'] = row['Program Cost']
    # (3) = Bach Degree
    elif row['Degree Type'] == 3:
        row['Total Cost'] = row['Annual Cost']*4
    # (2) = A.A Degree
    elif row['Degree Type'] == 2:
        row['Total Cost'] = row['Annual Cost']*2
    # If not an A.A or Bach, we are assumming it is a 1 year certificate
    else:
        row['Total Cost'] = row['Annual Cost']
school_df.head()
# Out:
#                                                 School Name School State  \
# 449490                Palm Beach Academy of Health & Beauty           FL
# 449506                                        SABER College           FL
# 449533    Pensacola School of Massage Therapy & Health C...           FL
# 449959                       Paul Mitchell the School-Tampa           FL
# 40884402        Florida National University Training Center           FL
#
#          Degree Type Program Cost Annual Cost Total Cost
# 449490             1        25572        None      25572
# 449506             2        19233        None      19233
# 449533             1        21608        None      21608
# 449959             1        21596        None      21596
# 40884402           2         None        None       None

# %% [markdown]
# ## Step 5: Clean School Data

# %%
# Removing schools that are not needed for data
to_remove = ['Beauty', 'Therapy', 'Med', 'Salon', 'Spa', 
             'Pet', 'Welding', 'Cosmetology', 'Massage', 'Nursing', 
             'Barber', 'Art', 'Airline', 'Law', 'Paul Mitchell', 
             'Neurosomatic', 'Personal Training', 'Seminary', 'Aveda', 'Mechanic', 
             'Bible', 'Hair', 'Aeronautical', 'Ultrasound', 'Aviation', 
             'Health', 'Midwifery', 'Aerospace', 'Professional Hands', 'Rabbinical']
clean_schools = school_df
for word in to_remove:
    clean_schools = clean_schools[clean_schools['School Name'].str.contains(word) == False]

# Dropping null rows
clean_schools = clean_schools.dropna(subset=['Total Cost', 'Degree Type'])

# %% [markdown]
# ## Step 6: Write Clean Data to CSV Files

# %%
occupation_df.to_csv("Clean_Data/CareerOneStop.csv", index=False, header=True)
clean_schools.to_csv('Clean_schools.csv', header=True)
