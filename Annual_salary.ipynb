# %%
# Importing Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as sts
import os

# %%
# Bring in Occupation data file
file = os.path.join('Clean_Data', 'Clean_Occupations.csv')

# Read Occupations
jobs_df = pd.read_csv(file)

# Display csv
jobs_df.head()
# Out:
#                               Occupation                    Career Pathway  \
# 0         Business Intelligence Analysts  Information Support and Services
# 1        Computer Occupations, All Other  Information Support and Services
# 2  Computer Systems Engineers/Architects  Information Support and Services
# 3      Computer User Support Specialists  Information Support and Services
# 4           Data Warehousing Specialists  Information Support and Services
#
#                                OnetTitle  \
# 0         Business Intelligence Analysts
# 1        Computer Occupations, All Other
# 2  Computer Systems Engineers/Architects
# 3      Computer User Support Specialists
# 4           Data Warehousing Specialists
#
#                                      OnetDescription  Annual Wage - Pct10  \
# 0  Produce financial and market intelligence by q...                44810
# 1    All computer occupations not listed separately.                31020
# 2  Design and develop solutions to complex applic...                31020
# 3  Provide technical assistance to computer users...                30040
# 4  Design, model, or implement corporate data war...                45430
#
#    Annual Wage - Pct25  Annual Wage - Median  Annual Wage - Pct75  \
# 0                54300                 64250                98980
# 1                45760                 71250                98880
# 2                45760                 71250                98880
# 3                36570                 46970                61660
# 4                63700                 90230               116170
#
#    Annual Wage - Pct90  Hourly Wage - Pct10  ...  EducationLevel_5  \
# 0               138330                21.55  ...              37.5
# 1               123080                14.91  ...              43.6
# 2               123080                14.91  ...              43.6
# 3                79350                14.44  ...              37.0
# 4               134290                21.84  ...              46.9
#
#    EducationLevel_6  EducationLevel_7  EducationCode           EducationTitle  \
# 0              36.0              14.5              3        Bachelor's degree
# 1              20.0               2.2              3        Bachelor's degree
# 2              20.0               2.2              3        Bachelor's degree
# 3              10.7               1.0              6  Some college, no degree
# 4              25.2               2.7              3        Bachelor's degree
#
#   ExperienceCode     ExperienceTitle  TrainingCode           TrainingTitle  \
# 0              3  No work experience             6  No on-the-job training
# 1              3  No work experience             6  No on-the-job training
# 2              3  No work experience             6  No on-the-job training
# 3              3  No work experience             6  No on-the-job training
# 4              3  No work experience             6  No on-the-job training
#
#                             EducationOccupationTitle
# 0  Data Scientists and Mathematical Science Occup...
# 1                    Computer Occupations, All Other
# 2                    Computer Occupations, All Other
# 3                  Computer User Support Specialists
# 4             Database Administrators and Architects
#
# [5 rows x 30 columns]

# %%
# Create bar plot with x and y values
x_axis = jobs_df['Occupation']
y_axis = jobs_df['Annual Wage - Median']

# Set Fig size
plt.figure(figsize=(17,5))

# Generate bar plot with matplotlib
plt.bar(x_axis, y_axis, width = 0.70)
plt.xticks(rotation='vertical')

# Set axis labels/limits for plot
plt.title('Annual Median Salary by Occupation', fontsize=13, fontweight='bold')
plt.xlabel('Occupation Title', fontsize=11, fontweight='bold')
plt.ylabel('Annual Median Salary ($)', fontsize=11, fontweight='bold')
plt.xlim(-0.5,25.5)
plt.ylim(30000,110000)

# Display bar plot
plt.show()

# %%
# Create bar plot with x and y values
x_axis = jobs_df['Occupation']
y_axis = jobs_df['Annual Wage - Pct10']

# Set Fig size
plt.figure(figsize=(17,5))

# Generate bar plot with matplotlib
plt.bar(x_axis, y_axis, width = 0.70)
plt.xticks(rotation='vertical')

# Set axis labels/limits for plot
plt.title('Lowest Annual Salary Level by Occupation', fontsize=13, fontweight='bold')
plt.xlabel('Occupation Title', fontsize=11, fontweight='bold')
plt.ylabel('Lowest Annual Salary Level ($)', fontsize=11, fontweight='bold')
plt.xlim(-0.5,25.5)

# Display bar plot
plt.show()

# %%
# Create bar plot with x and y values
x_axis = jobs_df['Occupation']
y_axis = jobs_df['Annual Wage - Pct90']

# Set Fig size
plt.figure(figsize=(17,5))

# Generate bar plot with matplotlib
plt.bar(x_axis, y_axis, width = 0.70)
plt.xticks(rotation='vertical')

# Set axis labels/limits for plot
plt.title('Highest Annual Salary Level by Occupation', fontsize=13, fontweight='bold')
plt.xlabel('Occupation Title', fontsize=11, fontweight='bold')
plt.ylabel('Highest Annual Salary Level ($)', fontsize=11, fontweight='bold')
plt.xlim(-0.5,25.5)
plt.ylim(60000,160000)

# Display bar plot
plt.show()
